# %%
#Challenge 1: Fork Languages
#https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/forks

# %%
# your code here
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
api_token = 

url = "https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/forks"
#url = "https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018"

headers = {'Authorization': 'token %s' % api_token}
#headers = {'Authorization': 'token {}'.format(api_token)}

r = requests.post(url, headers=headers)

response = requests.get(url, headers=headers)
results = response.json()
results

df = json_normalize(results)
df
# Out:
#                                           archive_url  archived  \
# 0   https://api.github.com/repos/gggfaria/mad-oct-...     False
# 1   https://api.github.com/repos/nancyulric/mad-oc...     False
# 2   https://api.github.com/repos/lmartinezruizit/d...     False
# 3   https://api.github.com/repos/eye8/madrid-oct-2...     False
# 4   https://api.github.com/repos/ArieHassan/madrid...     False
# 5   https://api.github.com/repos/cmvalma/madrid-oc...     False
# 6   https://api.github.com/repos/criraca/madrid-oc...     False
# 7   https://api.github.com/repos/boyander/madrid-o...     False
# 8   https://api.github.com/repos/AlbertoCastellano...     False
# 9   https://api.github.com/repos/elenajpp/madrid-o...     False
# 10  https://api.github.com/repos/pablobarrio/madri...     False
# 11  https://api.github.com/repos/miriammg/madrid-o...     False
# 12  https://api.github.com/repos/albertogcmr/madri...     False
# 13  https://api.github.com/repos/marisfont/madrid-...     False
#
# ...

# %%
df.columns
# Out:
# Index(['archive_url', 'archived', 'assignees_url', 'blobs_url', 'branches_url',
#        'clone_url', 'collaborators_url', 'comments_url', 'commits_url',
#        'compare_url', 'contents_url', 'contributors_url', 'created_at',
#        'default_branch', 'deployments_url', 'description', 'disabled',
#        'downloads_url', 'events_url', 'fork', 'forks', 'forks_count',
#        'forks_url', 'full_name', 'git_commits_url', 'git_refs_url',
#        'git_tags_url', 'git_url', 'has_downloads', 'has_issues', 'has_pages',
#        'has_projects', 'has_wiki', 'homepage', 'hooks_url', 'html_url', 'id',
#        'issue_comment_url', 'issue_events_url', 'issues_url', 'keys_url',
#        'labels_url', 'language', 'languages_url', 'license', 'license.key',
#        'license.name', 'license.node_id', 'license.spdx_id', 'license.url',
#        'merges_url', 'milestones_url', 'mirror_url', 'name', 'node_id',
#        'notifications_url', 'open_issues', 'open_issues_count',
# ...

# %%
df.language.unique()
# Out:
# array(['Jupyter Notebook', 'HTML', 'Python'], dtype=object)

# %%
#Challenge 2: Count Commits

# %%
# j'ai modifié la date car au 15/06/2019 il n'y a pas eu de commit.

url = "https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/commits?since=2019-01-01"
api_token = 
headers = {'Authorization': 'token %s' % api_token}

response = requests.get(url, headers=headers)
results = response.json()
results
len(results)

#df = json_normalize(results)
#df
# Out:
# 30

# %%
l = [1, 2, 3]
li = []
for x in l:
    li.append(x)
print(li)
# Out:
# [1, 2, 3]

# %%
df.columns
# Out:
# Index(['archive_url', 'archived', 'assignees_url', 'blobs_url', 'branches_url',
#        'clone_url', 'collaborators_url', 'comments_url', 'commits_url',
#        'compare_url', 'contents_url', 'contributors_url', 'created_at',
#        'default_branch', 'deployments_url', 'description', 'disabled',
#        'downloads_url', 'events_url', 'fork', 'forks', 'forks_count',
#        'forks_url', 'full_name', 'git_commits_url', 'git_refs_url',
#        'git_tags_url', 'git_url', 'has_downloads', 'has_issues', 'has_pages',
#        'has_projects', 'has_wiki', 'homepage', 'hooks_url', 'html_url', 'id',
#        'issue_comment_url', 'issue_events_url', 'issues_url', 'keys_url',
#        'labels_url', 'language', 'languages_url', 'license', 'license.key',
#        'license.name', 'license.node_id', 'license.spdx_id', 'license.url',
#        'merges_url', 'milestones_url', 'mirror_url', 'name', 'node_id',
#        'notifications_url', 'open_issues', 'open_issues_count',
# ...

# %%
len(df['commits_url'])
# Out:
# 14

# %%
#Challenge 3: Hidden Cold Joke

# %%
#https://github.com/ironhack-datalabs/scavenger
url = "https://api.github.com/repos/ironhack-datalabs/scavenger/contents"
api_token = 
headers = {'Authorization': 'token %s' % api_token}
response = requests.get(url, headers=headers)
results = response.json()
print(results)
# Out:
# [{'name': '.gitignore', 'path': '.gitignore', 'sha': 'e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf', 'size': 10, 'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master', 'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore', 'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf', 'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/.gitignore', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master', 'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf', 'html': 'https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore'}}, {'name': '15024', 'path': '15024', 'sha': '2945e51c87ad5da893c954afcf092f06343bbb7d', 'size': 0, 'url': 'https://api.github.com/repos/ironhack-datalabs/scaven
# ...

# %%
#pd.DataFrame(results)

# %%
flattened_data = json_normalize(results)
flattened_data[:2]
# Out:
#                                           _links.git  \
# 0  https://api.github.com/repos/ironhack-datalabs...
# 1  https://api.github.com/repos/ironhack-datalabs...
#
#                                          _links.html  \
# 0  https://github.com/ironhack-datalabs/scavenger...
# 1  https://github.com/ironhack-datalabs/scavenger...
#
#                                          _links.self  \
# 0  https://api.github.com/repos/ironhack-datalabs...
# 1  https://api.github.com/repos/ironhack-datalabs...
#
#                                         download_url  \
# 0  https://raw.githubusercontent.com/ironhack-dat...
# 1                                               None
#
#                                              git_url  \
# 0  https://api.github.com/repos/ironhack-datalabs...
# 1  https://api.github.com/repos/ironhack-datalabs...
#
#                                             html_url        name        path  \
# ...

# %%
dossiers = []
for name in flattened_data['path']:
    dossiers.append(name)
print(dossiers)
# Out:
# ['.gitignore', '15024', '15534', '17020', '30351', '40303', '44639', '45525', '47222', '47830', '49418', '50896', '55417', '55685', '60224', '64880', '66032', '68848', '70751', '70985', '88596', '89046', '89338', '91701', '97881', '98750']

# %%
code = []
for path in dossiers[1:]:
    url= f"https://api.github.com/repos/ironhack-datalabs/scavenger/contents/{path}"
    response = requests.get(url, headers=headers)
    results = response.json()
    for file in results:
        url = file['download_url']
        res = requests.get(url)
        
        
        code.append(res.content)
print(code)
# Out:
# [b'of\n', b'', b'', b'', b'spent\n', b'20\n', b'', b'', b'time\n', b'', b'', b'need\n', b'', b'', b'to\n', b'', b'', b'percent\n', b'', b'', b'complaining\n', b'', b'', b'is\n', b'data.\n', b'', b'', b'preparing\n', b'', b'', b'of\n', b'', b'', b'', b'data,\n', b'', b'', b'prepare\n', b'', b'', b'the\n', b'', b'', b'science,\n', b'', b'', b'', b'', b'', b'', b'', b'', b'80\n', b'', b'', b'about\n', b'', b'', b'', b'spent\n', b'', b'', b'data\n', b'', b'', b'', b'', b'', b'', b'percent\n', b'', b'', b'', b'time\n', b'', b'', b'is\n', b'', b'', b'', b'In\n', b'', b'']

# %%
fichiers= []
for path in dossiers[1:]:
    url= f"https://api.github.com/repos/ironhack-datalabs/scavenger/contents/{path}"
    response = requests.get(url, headers=headers)
    results = response.json()
    for file in results:
        url = file['html_url']
        res = requests.get(url)
        
        
        fichiers.append(res.content)
print(fichiers)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
results[0].keys()

# %%
requests.get(results[0]['download_url']).content
