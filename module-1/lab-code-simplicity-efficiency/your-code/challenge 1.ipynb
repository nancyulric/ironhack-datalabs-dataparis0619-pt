# %%
print('Welcome to this calculator!')
print('It can add and subtract whole numbers from zero to five in English word')


def operator_choice():
    operator = input('What do you want to do? plus or minus: ')
    if operator == 'plus' or 'minus':
        return operator
    else:
        print('Please enter a sign beetween plus or minus')
        return operator_choice()
        
def number_1_choice():
    number_1 = input('Please choose your first number (zero to five): ')
    if number_1 == 'zero' or 'one' or 'two' or 'three' or 'four' or 'five':
        return number_1
    else:
        print("Please enter a number beetween zero and five in English words")
        return number_1_choice()

def number_2_choice():
    number_2 = input('Please choose your second number (zero to five): ')
    if number_2 == 'zero' or 'one' or 'two' or 'three' or 'four' or 'five':
        return number_2
    else:
        print("Please enter a number beetween zero and five in English words")
        return number_2_choice()

def super_calculator():
    a = number_1_choice()
    b = operator_choice()
    c = number_2_choice()
    
    if a == 'zero' and b == 'plus'  and c == 'zero':
        return ("zero plus zero equals zero")
    if a == 'zero' and b == 'plus'  and c == 'one':
        return ("zero plus one equals one")
    if a == 'zero' and b == 'plus'  and c == 'two':
        return ("zero plus two equals two")
    if a == 'zero' and b == 'plus'  and c == 'three':
        return ("zero plus three equals three")
    if a == 'zero' and b == 'plus'  and c == 'four':
        return ("zero plus four equals four")
    if a == 'zero' and b == 'plus'  and c == 'five':
        return ("zero plus five equals five")

    if a == 'one' and b == 'plus'  and c == 'zero':
        return ("one plus zero equals one")
    if a == 'one' and b == 'plus'  and c == 'one':
        return ("one plus one equals two")
    if a == 'one' and b == 'plus'  and c == 'two':
        return ("one plus two equals three")
    if a == 'one' and b == 'plus'  and c == 'three':
        return ("one plus three equals four")
    if a == 'one' and b == 'plus'  and c == 'four':
        return ("one plus four equals five")
    if a == 'one' and b == 'plus'  and c == 'five':
        return ("one plus five equals six")
    
    if a == 'two' and b == 'plus'  and c == 'zero':
        return ("two plus zero equals two")
    if a == 'two' and b == 'plus'  and c == 'one':
        return ("two plus one equals three")
    if a == 'two' and b == 'plus'  and c == 'two':
        return ("two plus two equals four")
    if a == 'two' and b == 'plus'  and c == 'three':
        return ("two plus three equals five")
    if a == 'two' and b == 'plus'  and c == 'four':
        return ("two plus four equals six")
    if a == 'two' and b == 'plus'  and c == 'five':
        return ("two plus five equals seven")
    
    if a == 'three' and b == 'plus'  and c == 'zero':
        return ("three plus zero equals three")
    if a == 'three' and b == 'plus'  and c == 'one':
        return ("three plus one equals four")
    if a == 'three' and b == 'plus'  and c == 'two':
        return ("three plus two equals five")
    if a == 'three' and b == 'plus'  and c == 'three':
        return ("three plus three equals six")
    if a == 'three' and b == 'plus'  and c == 'four':
        return ("three plus four equals seven")
    if a == 'three' and b == 'plus'  and c == 'five':
        return ("three plus five equals eight")
    
    if a == 'four' and b == 'plus'  and c == 'zero':
        return ("four plus zero equals four")
    if a == 'four' and b == 'plus'  and c == 'one':
        return ("four plus one equals five")
    if a == 'four' and b == 'plus'  and c == 'two':
        return ("four plus two equals six")
    if a == 'four' and b == 'plus'  and c == 'three':
        return ("four plus three equals seven")
    if a == 'four' and b == 'plus'  and c == 'four':
        return ("four plus four equals eight")
    if a == 'four' and b == 'plus'  and c == 'five':
        return ("four plus five equals nine")
    
    if a == 'five' and b == 'plus'  and c == 'zero':
        return ("five plus zero equals five")
    if a == 'five' and b == 'plus'  and c == 'one':
        return ("five plus one equals six")
    if a == 'five' and b == 'plus'  and c == 'two':
        return ("five plus two equals seven")
    if a == 'five' and b == 'plus'  and c == 'three':
        return ("five plus three equals eight")
    if a == 'five' and b == 'plus'  and c == 'four':
        return ("five plus four equals nine")
    if a == 'five' and b == 'plus'  and c == 'five':
        return ("five plus five equals ten")

    if a == 'zero' and b == 'minus' and c == 'zero':
        return ("zero minus zero equals zero")
    if a == 'zero' and b == 'minus' and c == 'one':
        return ("zero minus one equals negative one")
    if a == 'zero' and b == 'minus' and c == 'two':
        return ("zero minus two equals negative two")
    if a == 'zero' and b == 'minus' and c == 'three':
        return ("zero minus three equals negative three")
    if a == 'zero' and b == 'minus' and c == 'four':
        return ("zero minus four equals negative four")
    if a == 'zero' and b == 'minus' and c == 'five':
        return ("zero minus five equals negative five")
    
    if a == 'one' and b == 'minus' and c == 'zero':
        return ("one minus zero equals one")
    if a == 'one' and b == 'minus' and c == 'one':
        return ("one minus one equals zero")
    if a == 'one' and b == 'minus' and c == 'two':
        return ("one minus two equals negative one")
    if a == 'one' and b == 'minus' and c == 'three':
        return ("one minus three equals negative three")
    if a == 'one' and b == 'minus' and c == 'four':
        return ("one minus four equals negative three")
    if a == 'one' and b == 'minus' and c == 'five':
        return ("one minus five equals negative four")
        
    if a == 'two' and b == 'minus' and c == 'zero':
        return ("two minus zero equals two")
    if a == 'two' and b == 'minus' and c == 'one':
        return ("two minus one equals one")
    if a == 'two' and b == 'minus' and c == 'two':
        return ("two minus two equals zero")
    if a == 'two' and b == 'minus' and c == 'three':
        return ("two minus three equals negative one")
    if a == 'two' and b == 'minus' and c == 'four':
        return ("two minus four equals negative two")
    if a == 'two' and b == 'minus' and c == 'five':
        return ("two minus five equals negative three")
        
    if a == 'three' and b == 'minus' and c == 'zero':
        return ("three minus zero equals three")
    if a == 'three' and b == 'minus' and c == 'one':
        return ("three minus one equals two")
    if a == 'three' and b == 'minus' and c == 'two':
        return ("three minus two equals one")
    if a == 'three' and b == 'minus' and c == 'three':
        return ("three minus three equals zero")
    if a == 'three' and b == 'minus' and c == 'four':
        return ("three minus four equals negative one")
    if a == 'three' and b == 'minus' and c == 'five':
        return ("three minus five equals negative two")
        
    if a == 'four' and b == 'minus' and c == 'zero':
        return ("four minus zero equals four")
    if a == 'four' and b == 'minus' and c == 'one':
        return ("four minus one equals three")
    if a == 'four' and b == 'minus' and c == 'two':
        return ("four minus two equals two")
    if a == 'four' and b == 'minus' and c == 'three':
        return ("four minus three equals one")
    if a == 'four' and b == 'minus' and c == 'four':
        return ("four minus four equals zero")
    if a == 'four' and b == 'minus' and c == 'five':
        return ("four minus five equals negative one")
        
    if a == 'five' and b == 'minus' and c == 'zero':
        return ("five minus zero equals five")
    if a == 'five' and b == 'minus' and c == 'one':
        return ("five minus one equals four")
    if a == 'five' and b == 'minus' and c == 'two':
        return ("five minus two equals three")
    if a == 'five' and b == 'minus' and c == 'three':
        return ("five minus three equals two")
    if a == 'five' and b == 'minus' and c == 'four':
        return ("five minus four equals one")
    if a == 'five' and b == 'minus' and c == 'five':
        return ("five minus five equals zero")

results = super_calculator()
print(results)
print("Thanks for using this calculator, goodbye :)")
# Out:
# Welcome to this calculator!
# It can add and subtract whole numbers from zero to five in English word
# Please choose your first number (zero to five): zero
# What do you want to do? plus or minus: plus
# Please choose your second number (zero to five): five
# zero plus five equals five
# Thanks for using this calculator, goodbye :)
